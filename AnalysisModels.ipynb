# %%
import torch

# %%
model = torch.load("TrainingCNNGRUClassifier/Epoch_50/model_epoch_50.pt")
print(model)
# Out:
# OrderedDict({'cnn.0.weight': tensor([[[-6.1490e-02, -3.3075e-01,  2.5901e-01],
#          [ 2.5505e-01, -1.8780e-01, -2.0313e-01]],
#
#         [[ 3.7855e-01,  3.6462e-01,  2.3022e-01],
#          [ 3.2061e-01,  3.2060e-01,  1.0606e-01]],
#
#         [[ 2.9493e-01,  4.3943e-01, -1.2607e-02],
#          [-1.4183e-01, -2.5479e-01, -4.9265e-03]],
#
#         [[ 1.2210e-01, -2.6806e-01,  6.4967e-02],
#          [-1.2459e-01,  5.7119e-01, -1.1423e-01]],
#
#         [[ 9.5210e-02, -1.0752e-01,  8.2787e-02],
#          [ 3.4959e-01,  3.1778e-01, -3.1438e-01]],
#
#         [[ 6.6754e-02, -1.5764e-02, -3.8201e-02],
#          [ 5.0208e-01, -2.2227e-01, -3.3675e-01]],
#
#         [[ 1.8631e-01, -5.7261e-03, -1.0981e-01],
#          [ 8.0651e-01,  2.9685e-01,  1.0941e-01]],
#
#         [[ 5.0806e-01,  3.1422e-01,  3.2020e-01],
#          [-1.7931e-01, -1.1329e-01, -9.4730e-02]],
#
#         [[-9.2587e-03,  1.8414e-01, -1.3496e-01],
#          [ 2.2724e-01, -3.8354e-01,  1.1116e-01]],
#
# ...

# %%
print(type(model))
# Out:
# <class 'collections.OrderedDict'>

# %%
print(model.keys())
# Out:
# odict_keys(['cnn.0.weight', 'cnn.0.bias', 'cnn.1.weight', 'cnn.1.bias', 'cnn.1.running_mean', 'cnn.1.running_var', 'cnn.1.num_batches_tracked', 'gru.weight_ih_l0', 'gru.weight_hh_l0', 'gru.bias_ih_l0', 'gru.bias_hh_l0', 'gru.weight_ih_l0_reverse', 'gru.weight_hh_l0_reverse', 'gru.bias_ih_l0_reverse', 'gru.bias_hh_l0_reverse', 'fc.0.weight', 'fc.0.bias', 'fc.1.weight', 'fc.1.bias'])
