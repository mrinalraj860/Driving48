# %%
import pandas as pd
import re
from difflib import get_close_matches
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def normalize_text(s):
    return re.sub(r'[^a-zA-Z0-9 ]', '', s.lower().strip())

def join_tokens(row):
    return ' '.join([str(x).strip() for x in row if pd.notna(x)])

def get_best_match(label, vocab_list):
    label_norm = normalize_text(label)
    vocab_norm = [normalize_text(v) for v in vocab_list]

    # Tier 1: Close string match
    close = get_close_matches(label_norm, vocab_norm, n=1, cutoff=0.85)
    if close:
        return close[0], 'best'

    # Tier 2: Jaccard token match
    label_tokens = set(label_norm.split())
    best_score = 0
    best_match = None
    for v in vocab_norm:
        v_tokens = set(v.split())
        score = len(label_tokens & v_tokens) / len(label_tokens | v_tokens)
        if score > best_score:
            best_score = score
            best_match = v
    if best_score > 0.3:
        return best_match, 'ok'

    # Tier 3: TF-IDF fallback
    tfidf = TfidfVectorizer().fit([label_norm] + vocab_norm)
    sims = cosine_similarity(tfidf.transform([label_norm]), tfidf.transform(vocab_norm)).flatten()
    idx = sims.argmax()
    return vocab_norm[idx], 'fallback'

def match_finediving_to_vocab(df_finediving, df_vocab, vocab_col_range=('0', '3'), finediving_col_range=('0', None)):
    # Combine tokens into labels
    df_finediving = df_finediving.copy()
    df_vocab = df_vocab.copy()

    if finediving_col_range[1] is not None:
        df_finediving['label'] = df_finediving.loc[:, finediving_col_range[0]:finediving_col_range[1]].apply(join_tokens, axis=1)
    else:
        df_finediving['label'] = df_finediving.loc[:, finediving_col_range[0]:].apply(join_tokens, axis=1)

    df_vocab['label'] = df_vocab.loc[:, vocab_col_range[0]:vocab_col_range[1]].apply(join_tokens, axis=1)

    # Normalize and match
    vocab_list = df_vocab['label'].tolist()
    vocab_normalized = [normalize_text(label) for label in vocab_list]
    label_to_index = {label: idx for idx, label in zip(vocab_normalized, df_vocab.index)}

    matched_classes = []
    match_types = []

    for label in df_finediving['label']:
        match, mtype = get_best_match(label, vocab_list)
        matched_classes.append(match)
        match_types.append(mtype)

    df_finediving['matched_class'] = matched_classes
    df_finediving['match_type'] = match_types

    # Compute matched index
    df_finediving['matched_vocab_index'] = df_finediving['matched_class'].apply(
        lambda x: label_to_index.get(normalize_text(x), -1)
    )

    # Class-to-class summary
    class_to_vocab_matches = df_finediving.groupby('label')['matched_class'].agg(['count', lambda x: list(x.unique())])
    class_to_vocab_matches.columns = ['finediving_count', 'matched_diving48_classes']
    match_types_summary = df_finediving.groupby('label')['match_type'].value_counts().unstack(fill_value=0)
    final_summary = class_to_vocab_matches.merge(match_types_summary, left_index=True, right_index=True)
    final_summary = final_summary.sort_values(by='finediving_count', ascending=False)

    return df_finediving, final_summary

# %%
df_finediving = pd.read_csv("/Users/mrinalraj/Downloads/WebDownload/Preprocess/FineDivingClassLikeDiving38.csv")
df_vocab = pd.read_csv("df_vocab.csv")

df_result, class_summary = match_finediving_to_vocab(df_finediving, df_vocab)

# %%
df_result
# Out:
#       Unnamed: 0    id   code        0       1      2     3    4    5  \
# 0              0     1   407c   Inward   35som   TUCK   NaN  NaN  NaN
# 1              1     2   407c   Inward   35som   TUCK   NaN  NaN  NaN
# 2              2     3  5253b     Back  15Twis  25som  PIKE  NaN  NaN
# 3              3     4   407c   Inward   35som   TUCK   NaN  NaN  NaN
# 4              4     5  5253b     Back  15Twis  25som  PIKE  NaN  NaN
# ...          ...   ...    ...      ...     ...    ...   ...  ...  ...
# 2752        2995  2996  5253b     Back  15Twis  25som  PIKE  NaN  NaN
# 2753        2996  2997   109c  Forward   45som   TUCK   NaN  NaN  NaN
# 2754        2997  2998  5255b     Back  25Twis  25som  PIKE  NaN  NaN
# 2755        2998  2999  5253b     Back  15Twis  25som  PIKE  NaN  NaN
# 2756        2999  3000  5255b     Back  25Twis  25som  PIKE  NaN  NaN
#
#                        label              matched_class match_type  \
# 0          Inward 35som TUCK   inward 35som notwis tuck         ok
# 1          Inward 35som TUCK   inward 35som notwis tuck         ok
# 2     Back 15Twis 25som PIKE     back 25som 15twis pike         ok
# 3          Inward 35som TUCK   inward 35som notwis tuck         ok
# 4     Back 15Twis 25som PIKE     back 25som 15twis pike         ok
# ...                      ...                        ...        ...
# 2752  Back 15Twis 25som PIKE     back 25som 15twis pike         ok
# 2753      Forward 45som TUCK  forward 45som notwis tuck         ok
# 2754  Back 25Twis 25som PIKE     back 25som 25twis pike         ok
# 2755  Back 15Twis 25som PIKE     back 25som 15twis pike         ok
# 2756  Back 25Twis 25som PIKE     back 25som 25twis pike         ok
#
#       matched_vocab_index
# 0                      -1
# 1                      -1
# 2                      -1
# 3                      -1
# 4                      -1
# ...                   ...
# 2752                   -1
# 2753                   -1
# 2754                   -1
# 2755                   -1
# 2756                   -1
#
# [2757 rows x 13 columns]

# %%
class_summary
# Out:
#                                     finediving_count  \
# label
# Inward 35som TUCK                                345
# Forward 35som PIKE                               322
# Reverse 35som TUCK                               231
# Back 25som PIKE                                  205
# Back 15Twis 25som PIKE                           203
# Back 35som TUCK                                  159
# Forward 45som TUCK                               158
# Inward 25som PIKE                                132
# Forward 25som PIKE 2Twis                         110
# Forward 25som PIKE 1Twis                          94
# Reverse 05som PIKE                                87
# Reverse 25som PIKE                                82
# Back 25Twis 25som PIKE                            79
# Back 35som PIKE                                   73
# Back 05som PIKE                                   70
# Reverse 25som TUCK                                57
# Forward 15som PIKE                                36
# Inward 05som PIKE                                 36
# Forward 25som PIKE 3Twis                          36
# Reverse 15Twis 25som PIKE                         31
# Inward 15som PIKE                                 23
# Forward 05som PIKE                                22
# Reverse 35Twis 15som PIKE                         21
# Forward 35som TUCK                                18
# Inward 25som TUCK                                 18
# Back 25som TUCK                                   16
# Back 05Twis 15som PIKE                            12
# Back 25Twis 15som PIKE                            11
# Forward 15som PIKE 1Twis                           9
# Inward 35som PIKE                                  8
# Back 05Twis 25som PIKE                             7
# Forward 25som PIKE                                 6
# Inward 45som TUCK                                  5
# Forward 1som PIKE 2Twis 15som PIKE                 4
# Reverse 05Twis 15som PIKE                          4
# Back 15Twis 15som PIKE                             4
# Forward 35som PIKE 1Twis                           3
# Reverse 25Twis 25som PIKE                          3
# Reverse 25Twis 15som PIKE                          2
# Back 35Twis 15som PIKE                             2
# Reverse 15som TUCK                                 1
# Reverse 35Twis 15som TUCK                          1
# Reverse 3som TUCK                                  1
# Forward 35Twis 15som PIKE                          1
# Inward 1som PIKE                                   1
# Forward 45som PIKE                                 1
# Forward 25som TUCK 2Twis                           1
# Forward 1som PIKE 3Twis 25som PIKE                 1
# Forward 15Twis 25som PIKE                          1
# Forward 05Twis 2som PIKE                           1
# Back 25Twis 2som TUCK                              1
# Back 15Twis 2som PIKE                              1
# Reverse 45som TUCK                                 1
#
#                                        matched_diving48_classes  \
# label
# Inward 35som TUCK                    [inward 35som notwis tuck]
# Forward 35som PIKE                  [forward 35som notwis pike]
# Reverse 35som TUCK                  [reverse 35som notwis tuck]
# Back 25som PIKE                        [back 25som 15twis pike]
# Back 15Twis 25som PIKE                 [back 25som 15twis pike]
# Back 35som TUCK                        [back 35som notwis tuck]
# Forward 45som TUCK                  [forward 45som notwis tuck]
# Inward 25som PIKE                    [inward 25som notwis pike]
# Forward 25som PIKE 2Twis             [forward 25som 2twis pike]
# Forward 25som PIKE 1Twis             [forward 25som 1twis pike]
# Reverse 05som PIKE                  [reverse 15som notwis pike]
# Reverse 25som PIKE                  [reverse 25som 15twis pike]
# Back 25Twis 25som PIKE                 [back 25som 25twis pike]
# Back 35som PIKE                        [back 35som notwis pike]
# Back 05som PIKE                        [back 15som notwis pike]
# Reverse 25som TUCK                  [reverse 25som notwis tuck]
# Forward 15som PIKE                  [forward 15som notwis pike]
# Inward 05som PIKE                    [inward 15som notwis pike]
# Forward 25som PIKE 3Twis             [forward 25som 3twis pike]
# Reverse 15Twis 25som PIKE           [reverse 25som 15twis pike]
# Inward 15som PIKE                    [inward 15som notwis pike]
# Forward 05som PIKE                  [forward 15som notwis pike]
# Reverse 35Twis 15som PIKE           [reverse 15som 35twis free]
# Forward 35som TUCK                  [forward 35som notwis tuck]
# Inward 25som TUCK                    [inward 25som notwis tuck]
# Back 25som TUCK                        [back 25som notwis tuck]
# Back 05Twis 15som PIKE                 [back 15som 05twis free]
# Back 25Twis 15som PIKE                 [back 15som 25twis free]
# Forward 15som PIKE 1Twis             [forward 15som 1twis free]
# Inward 35som PIKE                      [back 35som notwis pike]
# Back 05Twis 25som PIKE                 [back 25som 15twis pike]
# Forward 25som PIKE                   [forward 25som 3twis pike]
# Inward 45som TUCK                   [forward 45som notwis tuck]
# Forward 1som PIKE 2Twis 15som PIKE   [forward 15som 2twis free]
# Reverse 05Twis 15som PIKE           [reverse 15som 05twis free]
# Back 15Twis 15som PIKE                 [back 15som 15twis free]
# Forward 35som PIKE 1Twis             [forward 25som 1twis pike]
# Reverse 25Twis 25som PIKE              [back 25som 25twis pike]
# Reverse 25Twis 15som PIKE           [reverse 15som 25twis free]
# Back 35Twis 15som PIKE                 [back 15som notwis pike]
# Reverse 15som TUCK                     [back 15som notwis tuck]
# Reverse 35Twis 15som TUCK           [reverse 15som 35twis free]
# Reverse 3som TUCK                       [back 3som notwis tuck]
# Forward 35Twis 15som PIKE           [forward 15som notwis pike]
# Inward 1som PIKE                     [forward 1som notwis pike]
# Forward 45som PIKE                  [forward 15som notwis pike]
# Forward 25som TUCK 2Twis             [forward 25som 2twis pike]
# Forward 1som PIKE 3Twis 25som PIKE   [forward 25som 3twis pike]
# Forward 15Twis 25som PIKE              [back 25som 15twis pike]
# Forward 05Twis 2som PIKE            [forward 15som notwis pike]
# Back 25Twis 2som TUCK                   [back 2som 25twis free]
# Back 15Twis 2som PIKE                  [back 25som 15twis pike]
# Reverse 45som TUCK                  [forward 45som notwis tuck]
#
#                                    matched_vocab_indices  most_common_index  \
# label
# Inward 35som TUCK                                   [-1]                 -1
# Forward 35som PIKE                                  [-1]                 -1
# Reverse 35som TUCK                                  [-1]                 -1
# Back 25som PIKE                                     [-1]                 -1
# Back 15Twis 25som PIKE                              [-1]                 -1
# Back 35som TUCK                                     [-1]                 -1
# Forward 45som TUCK                                  [-1]                 -1
# Inward 25som PIKE                                   [-1]                 -1
# Forward 25som PIKE 2Twis                            [-1]                 -1
# Forward 25som PIKE 1Twis                            [-1]                 -1
# Reverse 05som PIKE                                  [-1]                 -1
# Reverse 25som PIKE                                  [-1]                 -1
# Back 25Twis 25som PIKE                              [-1]                 -1
# Back 35som PIKE                                     [-1]                 -1
# Back 05som PIKE                                     [-1]                 -1
# Reverse 25som TUCK                                  [-1]                 -1
# Forward 15som PIKE                                  [-1]                 -1
# Inward 05som PIKE                                   [-1]                 -1
# Forward 25som PIKE 3Twis                            [-1]                 -1
# Reverse 15Twis 25som PIKE                           [-1]                 -1
# Inward 15som PIKE                                   [-1]                 -1
# Forward 05som PIKE                                  [-1]                 -1
# Reverse 35Twis 15som PIKE                           [-1]                 -1
# Forward 35som TUCK                                  [-1]                 -1
# Inward 25som TUCK                                   [-1]                 -1
# Back 25som TUCK                                     [-1]                 -1
# Back 05Twis 15som PIKE                              [-1]                 -1
# Back 25Twis 15som PIKE                              [-1]                 -1
# Forward 15som PIKE 1Twis                            [-1]                 -1
# Inward 35som PIKE                                   [-1]                 -1
# Back 05Twis 25som PIKE                              [-1]                 -1
# Forward 25som PIKE                                  [-1]                 -1
# Inward 45som TUCK                                   [-1]                 -1
# Forward 1som PIKE 2Twis 15som PIKE                  [-1]                 -1
# Reverse 05Twis 15som PIKE                           [-1]                 -1
# Back 15Twis 15som PIKE                              [-1]                 -1
# Forward 35som PIKE 1Twis                            [-1]                 -1
# Reverse 25Twis 25som PIKE                           [-1]                 -1
# Reverse 25Twis 15som PIKE                           [-1]                 -1
# Back 35Twis 15som PIKE                              [-1]                 -1
# Reverse 15som TUCK                                  [-1]                 -1
# Reverse 35Twis 15som TUCK                           [-1]                 -1
# Reverse 3som TUCK                                   [-1]                 -1
# Forward 35Twis 15som PIKE                           [-1]                 -1
# Inward 1som PIKE                                    [-1]                 -1
# Forward 45som PIKE                                  [-1]                 -1
# Forward 25som TUCK 2Twis                            [-1]                 -1
# Forward 1som PIKE 3Twis 25som PIKE                  [-1]                 -1
# Forward 15Twis 25som PIKE                           [-1]                 -1
# Forward 05Twis 2som PIKE                            [-1]                 -1
# Back 25Twis 2som TUCK                               [-1]                 -1
# Back 15Twis 2som PIKE                               [-1]                 -1
# Reverse 45som TUCK                                  [-1]                 -1
#
#                                     best   ok
# label
# Inward 35som TUCK                      0  345
# Forward 35som PIKE                     0  322
# Reverse 35som TUCK                     0  231
# Back 25som PIKE                        0  205
# Back 15Twis 25som PIKE                 0  203
# Back 35som TUCK                        0  159
# Forward 45som TUCK                     0  158
# Inward 25som PIKE                      0  132
# Forward 25som PIKE 2Twis               0  110
# Forward 25som PIKE 1Twis               0   94
# Reverse 05som PIKE                     0   87
# Reverse 25som PIKE                     0   82
# Back 25Twis 25som PIKE                 0   79
# Back 35som PIKE                        0   73
# Back 05som PIKE                        0   70
# Reverse 25som TUCK                     0   57
# Forward 15som PIKE                     0   36
# Inward 05som PIKE                      0   36
# Forward 25som PIKE 3Twis               0   36
# Reverse 15Twis 25som PIKE              0   31
# Inward 15som PIKE                      0   23
# Forward 05som PIKE                     0   22
# Reverse 35Twis 15som PIKE              0   21
# Forward 35som TUCK                     0   18
# Inward 25som TUCK                      0   18
# Back 25som TUCK                        0   16
# Back 05Twis 15som PIKE                 0   12
# Back 25Twis 15som PIKE                 0   11
# Forward 15som PIKE 1Twis               0    9
# Inward 35som PIKE                      0    8
# Back 05Twis 25som PIKE                 0    7
# Forward 25som PIKE                     6    0
# Inward 45som TUCK                      0    5
# Forward 1som PIKE 2Twis 15som PIKE     0    4
# Reverse 05Twis 15som PIKE              0    4
# Back 15Twis 15som PIKE                 0    4
# Forward 35som PIKE 1Twis               0    3
# Reverse 25Twis 25som PIKE              0    3
# Reverse 25Twis 15som PIKE              0    2
# Back 35Twis 15som PIKE                 0    2
# Reverse 15som TUCK                     0    1
# Reverse 35Twis 15som TUCK              0    1
# Reverse 3som TUCK                      0    1
# Forward 35Twis 15som PIKE              0    1
# Inward 1som PIKE                       0    1
# Forward 45som PIKE                     0    1
# Forward 25som TUCK 2Twis               0    1
# Forward 1som PIKE 3Twis 25som PIKE     0    1
# Forward 15Twis 25som PIKE              0    1
# Forward 05Twis 2som PIKE               0    1
# Back 25Twis 2som TUCK                  0    1
# Back 15Twis 2som PIKE                  0    1
# Reverse 45som TUCK                     0    1

# %%
vocabMergedAction = df_vocab[['0', '1', '2', '3']].astype(str).agg(' '.join, axis=1).str.lower().str.strip().reset_index()

# %%
vocabMergedAction
# Out:
#     index                          0
# 0       0     back 15som 05twis free
# 1       1     back 15som 15twis free
# 2       2     back 15som 25twis free
# 3       3     back 15som notwis pike
# 4       4     back 15som notwis tuck
# 5       5     back 25som 15twis pike
# 6       6     back 25som 25twis pike
# 7       7     back 25som notwis pike
# 8       8     back 25som notwis tuck
# 9       9      back 2som 15twis free
# 10     10      back 2som 25twis free
# 11     11     back 35som notwis pike
# 12     12     back 35som notwis tuck
# 13     13      back 3som notwis pike
# 14     14      back 3som notwis tuck
# 15     15      back dive notwis pike
# 16     16      back dive notwis tuck
# 17     17   forward 15som 1twis free
# 18     18   forward 15som 2twis free
# 19     19  forward 15som notwis pike
# 20     20   forward 1som notwis pike
# 21     21   forward 25som 1twis pike
# 22     22   forward 25som 2twis pike
# 23     23   forward 25som 3twis pike
# 24     24  forward 25som notwis pike
# 25     25  forward 25som notwis tuck
# 26     26  forward 35som notwis pike
# 27     27  forward 35som notwis tuck
# 28     28  forward 45som notwis tuck
# 29     29   forward dive notwis pike
# 30     30    forward dive notwis str
# 31     31   inward 15som notwis pike
# 32     32   inward 15som notwis tuck
# 33     33   inward 25som notwis pike
# 34     34   inward 25som notwis tuck
# 35     35   inward 35som notwis tuck
# 36     36    inward dive notwis pike
# 37     37  reverse 15som 05twis free
# 38     38  reverse 15som 15twis free
# 39     39  reverse 15som 25twis free
# 40     40  reverse 15som 35twis free
# 41     41  reverse 15som notwis pike
# 42     42  reverse 25som 15twis pike
# 43     43  reverse 25som notwis pike
# 44     44  reverse 25som notwis tuck
# 45     45  reverse 35som notwis tuck
# 46     46   reverse dive notwis pike
# 47     47   reverse dive notwis tuck

# %%
vocabMergedAction[0]
# Out:
# 0        back 15som 05twis free
# 1        back 15som 15twis free
# 2        back 15som 25twis free
# 3        back 15som notwis pike
# 4        back 15som notwis tuck
# 5        back 25som 15twis pike
# 6        back 25som 25twis pike
# 7        back 25som notwis pike
# 8        back 25som notwis tuck
# 9         back 2som 15twis free
# 10        back 2som 25twis free
# 11       back 35som notwis pike
# 12       back 35som notwis tuck
# 13        back 3som notwis pike
# 14        back 3som notwis tuck
# 15        back dive notwis pike
# 16        back dive notwis tuck
# 17     forward 15som 1twis free
# 18     forward 15som 2twis free
# 19    forward 15som notwis pike
# 20     forward 1som notwis pike
# 21     forward 25som 1twis pike
# 22     forward 25som 2twis pike
# 23     forward 25som 3twis pike
# 24    forward 25som notwis pike
# 25    forward 25som notwis tuck
# 26    forward 35som notwis pike
# 27    forward 35som notwis tuck
# 28    forward 45som notwis tuck
# 29     forward dive notwis pike
# 30      forward dive notwis str
# 31     inward 15som notwis pike
# 32     inward 15som notwis tuck
# 33     inward 25som notwis pike
# 34     inward 25som notwis tuck
# 35     inward 35som notwis tuck
# 36      inward dive notwis pike
# 37    reverse 15som 05twis free
# 38    reverse 15som 15twis free
# 39    reverse 15som 25twis free
# 40    reverse 15som 35twis free
# 41    reverse 15som notwis pike
# 42    reverse 25som 15twis pike
# 43    reverse 25som notwis pike
# 44    reverse 25som notwis tuck
# 45    reverse 35som notwis tuck
# 46     reverse dive notwis pike
# 47     reverse dive notwis tuck
# Name: 0, dtype: object

# %%
class_summary['matched_diving48_classes_str'] = class_summary['matched_diving48_classes'].apply(lambda x: x[0].lower().strip() if isinstance(x, list) and len(x) > 0 else '')
class_summary
# Out:
#                                     finediving_count  \
# label
# Inward 35som TUCK                                345
# Forward 35som PIKE                               322
# Reverse 35som TUCK                               231
# Back 25som PIKE                                  205
# Back 15Twis 25som PIKE                           203
# Back 35som TUCK                                  159
# Forward 45som TUCK                               158
# Inward 25som PIKE                                132
# Forward 25som PIKE 2Twis                         110
# Forward 25som PIKE 1Twis                          94
# Reverse 05som PIKE                                87
# Reverse 25som PIKE                                82
# Back 25Twis 25som PIKE                            79
# Back 35som PIKE                                   73
# Back 05som PIKE                                   70
# Reverse 25som TUCK                                57
# Forward 15som PIKE                                36
# Inward 05som PIKE                                 36
# Forward 25som PIKE 3Twis                          36
# Reverse 15Twis 25som PIKE                         31
# Inward 15som PIKE                                 23
# Forward 05som PIKE                                22
# Reverse 35Twis 15som PIKE                         21
# Forward 35som TUCK                                18
# Inward 25som TUCK                                 18
# Back 25som TUCK                                   16
# Back 05Twis 15som PIKE                            12
# Back 25Twis 15som PIKE                            11
# Forward 15som PIKE 1Twis                           9
# Inward 35som PIKE                                  8
# Back 05Twis 25som PIKE                             7
# Forward 25som PIKE                                 6
# Inward 45som TUCK                                  5
# Forward 1som PIKE 2Twis 15som PIKE                 4
# Reverse 05Twis 15som PIKE                          4
# Back 15Twis 15som PIKE                             4
# Forward 35som PIKE 1Twis                           3
# Reverse 25Twis 25som PIKE                          3
# Reverse 25Twis 15som PIKE                          2
# Back 35Twis 15som PIKE                             2
# Reverse 15som TUCK                                 1
# Reverse 35Twis 15som TUCK                          1
# Reverse 3som TUCK                                  1
# Forward 35Twis 15som PIKE                          1
# Inward 1som PIKE                                   1
# Forward 45som PIKE                                 1
# Forward 25som TUCK 2Twis                           1
# Forward 1som PIKE 3Twis 25som PIKE                 1
# Forward 15Twis 25som PIKE                          1
# Forward 05Twis 2som PIKE                           1
# Back 25Twis 2som TUCK                              1
# Back 15Twis 2som PIKE                              1
# Reverse 45som TUCK                                 1
#
#                                        matched_diving48_classes  \
# label
# Inward 35som TUCK                    [inward 35som notwis tuck]
# Forward 35som PIKE                  [forward 35som notwis pike]
# Reverse 35som TUCK                  [reverse 35som notwis tuck]
# Back 25som PIKE                        [back 25som 15twis pike]
# Back 15Twis 25som PIKE                 [back 25som 15twis pike]
# Back 35som TUCK                        [back 35som notwis tuck]
# Forward 45som TUCK                  [forward 45som notwis tuck]
# Inward 25som PIKE                    [inward 25som notwis pike]
# Forward 25som PIKE 2Twis             [forward 25som 2twis pike]
# Forward 25som PIKE 1Twis             [forward 25som 1twis pike]
# Reverse 05som PIKE                  [reverse 15som notwis pike]
# Reverse 25som PIKE                  [reverse 25som 15twis pike]
# Back 25Twis 25som PIKE                 [back 25som 25twis pike]
# Back 35som PIKE                        [back 35som notwis pike]
# Back 05som PIKE                        [back 15som notwis pike]
# Reverse 25som TUCK                  [reverse 25som notwis tuck]
# Forward 15som PIKE                  [forward 15som notwis pike]
# Inward 05som PIKE                    [inward 15som notwis pike]
# Forward 25som PIKE 3Twis             [forward 25som 3twis pike]
# Reverse 15Twis 25som PIKE           [reverse 25som 15twis pike]
# Inward 15som PIKE                    [inward 15som notwis pike]
# Forward 05som PIKE                  [forward 15som notwis pike]
# Reverse 35Twis 15som PIKE           [reverse 15som 35twis free]
# Forward 35som TUCK                  [forward 35som notwis tuck]
# Inward 25som TUCK                    [inward 25som notwis tuck]
# Back 25som TUCK                        [back 25som notwis tuck]
# Back 05Twis 15som PIKE                 [back 15som 05twis free]
# Back 25Twis 15som PIKE                 [back 15som 25twis free]
# Forward 15som PIKE 1Twis             [forward 15som 1twis free]
# Inward 35som PIKE                      [back 35som notwis pike]
# Back 05Twis 25som PIKE                 [back 25som 15twis pike]
# Forward 25som PIKE                   [forward 25som 3twis pike]
# Inward 45som TUCK                   [forward 45som notwis tuck]
# Forward 1som PIKE 2Twis 15som PIKE   [forward 15som 2twis free]
# Reverse 05Twis 15som PIKE           [reverse 15som 05twis free]
# Back 15Twis 15som PIKE                 [back 15som 15twis free]
# Forward 35som PIKE 1Twis             [forward 25som 1twis pike]
# Reverse 25Twis 25som PIKE              [back 25som 25twis pike]
# Reverse 25Twis 15som PIKE           [reverse 15som 25twis free]
# Back 35Twis 15som PIKE                 [back 15som notwis pike]
# Reverse 15som TUCK                     [back 15som notwis tuck]
# Reverse 35Twis 15som TUCK           [reverse 15som 35twis free]
# Reverse 3som TUCK                       [back 3som notwis tuck]
# Forward 35Twis 15som PIKE           [forward 15som notwis pike]
# Inward 1som PIKE                     [forward 1som notwis pike]
# Forward 45som PIKE                  [forward 15som notwis pike]
# Forward 25som TUCK 2Twis             [forward 25som 2twis pike]
# Forward 1som PIKE 3Twis 25som PIKE   [forward 25som 3twis pike]
# Forward 15Twis 25som PIKE              [back 25som 15twis pike]
# Forward 05Twis 2som PIKE            [forward 15som notwis pike]
# Back 25Twis 2som TUCK                   [back 2som 25twis free]
# Back 15Twis 2som PIKE                  [back 25som 15twis pike]
# Reverse 45som TUCK                  [forward 45som notwis tuck]
#
#                                    matched_vocab_indices  most_common_index  \
# label
# Inward 35som TUCK                                   [-1]                 -1
# Forward 35som PIKE                                  [-1]                 -1
# Reverse 35som TUCK                                  [-1]                 -1
# Back 25som PIKE                                     [-1]                 -1
# Back 15Twis 25som PIKE                              [-1]                 -1
# Back 35som TUCK                                     [-1]                 -1
# Forward 45som TUCK                                  [-1]                 -1
# Inward 25som PIKE                                   [-1]                 -1
# Forward 25som PIKE 2Twis                            [-1]                 -1
# Forward 25som PIKE 1Twis                            [-1]                 -1
# Reverse 05som PIKE                                  [-1]                 -1
# Reverse 25som PIKE                                  [-1]                 -1
# Back 25Twis 25som PIKE                              [-1]                 -1
# Back 35som PIKE                                     [-1]                 -1
# Back 05som PIKE                                     [-1]                 -1
# Reverse 25som TUCK                                  [-1]                 -1
# Forward 15som PIKE                                  [-1]                 -1
# Inward 05som PIKE                                   [-1]                 -1
# Forward 25som PIKE 3Twis                            [-1]                 -1
# Reverse 15Twis 25som PIKE                           [-1]                 -1
# Inward 15som PIKE                                   [-1]                 -1
# Forward 05som PIKE                                  [-1]                 -1
# Reverse 35Twis 15som PIKE                           [-1]                 -1
# Forward 35som TUCK                                  [-1]                 -1
# Inward 25som TUCK                                   [-1]                 -1
# Back 25som TUCK                                     [-1]                 -1
# Back 05Twis 15som PIKE                              [-1]                 -1
# Back 25Twis 15som PIKE                              [-1]                 -1
# Forward 15som PIKE 1Twis                            [-1]                 -1
# Inward 35som PIKE                                   [-1]                 -1
# Back 05Twis 25som PIKE                              [-1]                 -1
# Forward 25som PIKE                                  [-1]                 -1
# Inward 45som TUCK                                   [-1]                 -1
# Forward 1som PIKE 2Twis 15som PIKE                  [-1]                 -1
# Reverse 05Twis 15som PIKE                           [-1]                 -1
# Back 15Twis 15som PIKE                              [-1]                 -1
# Forward 35som PIKE 1Twis                            [-1]                 -1
# Reverse 25Twis 25som PIKE                           [-1]                 -1
# Reverse 25Twis 15som PIKE                           [-1]                 -1
# Back 35Twis 15som PIKE                              [-1]                 -1
# Reverse 15som TUCK                                  [-1]                 -1
# Reverse 35Twis 15som TUCK                           [-1]                 -1
# Reverse 3som TUCK                                   [-1]                 -1
# Forward 35Twis 15som PIKE                           [-1]                 -1
# Inward 1som PIKE                                    [-1]                 -1
# Forward 45som PIKE                                  [-1]                 -1
# Forward 25som TUCK 2Twis                            [-1]                 -1
# Forward 1som PIKE 3Twis 25som PIKE                  [-1]                 -1
# Forward 15Twis 25som PIKE                           [-1]                 -1
# Forward 05Twis 2som PIKE                            [-1]                 -1
# Back 25Twis 2som TUCK                               [-1]                 -1
# Back 15Twis 2som PIKE                               [-1]                 -1
# Reverse 45som TUCK                                  [-1]                 -1
#
#                                     best   ok matched_diving48_classes_str
# label
# Inward 35som TUCK                      0  345     inward 35som notwis tuck
# Forward 35som PIKE                     0  322    forward 35som notwis pike
# Reverse 35som TUCK                     0  231    reverse 35som notwis tuck
# Back 25som PIKE                        0  205       back 25som 15twis pike
# Back 15Twis 25som PIKE                 0  203       back 25som 15twis pike
# Back 35som TUCK                        0  159       back 35som notwis tuck
# Forward 45som TUCK                     0  158    forward 45som notwis tuck
# Inward 25som PIKE                      0  132     inward 25som notwis pike
# Forward 25som PIKE 2Twis               0  110     forward 25som 2twis pike
# Forward 25som PIKE 1Twis               0   94     forward 25som 1twis pike
# Reverse 05som PIKE                     0   87    reverse 15som notwis pike
# Reverse 25som PIKE                     0   82    reverse 25som 15twis pike
# Back 25Twis 25som PIKE                 0   79       back 25som 25twis pike
# Back 35som PIKE                        0   73       back 35som notwis pike
# Back 05som PIKE                        0   70       back 15som notwis pike
# Reverse 25som TUCK                     0   57    reverse 25som notwis tuck
# Forward 15som PIKE                     0   36    forward 15som notwis pike
# Inward 05som PIKE                      0   36     inward 15som notwis pike
# Forward 25som PIKE 3Twis               0   36     forward 25som 3twis pike
# Reverse 15Twis 25som PIKE              0   31    reverse 25som 15twis pike
# Inward 15som PIKE                      0   23     inward 15som notwis pike
# Forward 05som PIKE                     0   22    forward 15som notwis pike
# Reverse 35Twis 15som PIKE              0   21    reverse 15som 35twis free
# Forward 35som TUCK                     0   18    forward 35som notwis tuck
# Inward 25som TUCK                      0   18     inward 25som notwis tuck
# Back 25som TUCK                        0   16       back 25som notwis tuck
# Back 05Twis 15som PIKE                 0   12       back 15som 05twis free
# Back 25Twis 15som PIKE                 0   11       back 15som 25twis free
# Forward 15som PIKE 1Twis               0    9     forward 15som 1twis free
# Inward 35som PIKE                      0    8       back 35som notwis pike
# Back 05Twis 25som PIKE                 0    7       back 25som 15twis pike
# Forward 25som PIKE                     6    0     forward 25som 3twis pike
# Inward 45som TUCK                      0    5    forward 45som notwis tuck
# Forward 1som PIKE 2Twis 15som PIKE     0    4     forward 15som 2twis free
# Reverse 05Twis 15som PIKE              0    4    reverse 15som 05twis free
# Back 15Twis 15som PIKE                 0    4       back 15som 15twis free
# Forward 35som PIKE 1Twis               0    3     forward 25som 1twis pike
# Reverse 25Twis 25som PIKE              0    3       back 25som 25twis pike
# Reverse 25Twis 15som PIKE              0    2    reverse 15som 25twis free
# Back 35Twis 15som PIKE                 0    2       back 15som notwis pike
# Reverse 15som TUCK                     0    1       back 15som notwis tuck
# Reverse 35Twis 15som TUCK              0    1    reverse 15som 35twis free
# Reverse 3som TUCK                      0    1        back 3som notwis tuck
# Forward 35Twis 15som PIKE              0    1    forward 15som notwis pike
# Inward 1som PIKE                       0    1     forward 1som notwis pike
# Forward 45som PIKE                     0    1    forward 15som notwis pike
# Forward 25som TUCK 2Twis               0    1     forward 25som 2twis pike
# Forward 1som PIKE 3Twis 25som PIKE     0    1     forward 25som 3twis pike
# Forward 15Twis 25som PIKE              0    1       back 25som 15twis pike
# Forward 05Twis 2som PIKE               0    1    forward 15som notwis pike
# Back 25Twis 2som TUCK                  0    1        back 2som 25twis free
# Back 15Twis 2som PIKE                  0    1       back 25som 15twis pike
# Reverse 45som TUCK                     0    1    forward 45som notwis tuck

# %%
merged = class_summary.merge(vocabMergedAction, left_on='matched_diving48_classes_str', right_on=0, how='left')

print(merged.head())
# Out:
#                     label  finediving_count     matched_diving48_classes  \
# 0       Inward 35som TUCK               345   [inward 35som notwis tuck]
# 1      Forward 35som PIKE               322  [forward 35som notwis pike]
# 2      Reverse 35som TUCK               231  [reverse 35som notwis tuck]
# 3         Back 25som PIKE               205     [back 25som 15twis pike]
# 4  Back 15Twis 25som PIKE               203     [back 25som 15twis pike]
#
#   matched_vocab_indices  most_common_index  best   ok  \
# 0                  [-1]                 -1     0  345
# 1                  [-1]                 -1     0  322
# 2                  [-1]                 -1     0  231
# 3                  [-1]                 -1     0  205
# 4                  [-1]                 -1     0  203
#
#   matched_diving48_classes_str  index                          0
# 0     inward 35som notwis tuck     35   inward 35som notwis tuck
# 1    forward 35som notwis pike     26  forward 35som notwis pike
# 2    reverse 35som notwis tuck     45  reverse 35som notwis tuck
# 3       back 25som 15twis pike      5     back 25som 15twis pike
# 4       back 25som 15twis pike      5     back 25som 15twis pike

# %%
merged.head()
# Out:
#                     label  finediving_count     matched_diving48_classes  \
# 0       Inward 35som TUCK               345   [inward 35som notwis tuck]
# 1      Forward 35som PIKE               322  [forward 35som notwis pike]
# 2      Reverse 35som TUCK               231  [reverse 35som notwis tuck]
# 3         Back 25som PIKE               205     [back 25som 15twis pike]
# 4  Back 15Twis 25som PIKE               203     [back 25som 15twis pike]
#
#   matched_vocab_indices  most_common_index  best   ok  \
# 0                  [-1]                 -1     0  345
# 1                  [-1]                 -1     0  322
# 2                  [-1]                 -1     0  231
# 3                  [-1]                 -1     0  205
# 4                  [-1]                 -1     0  203
#
#   matched_diving48_classes_str  index                          0
# 0     inward 35som notwis tuck     35   inward 35som notwis tuck
# 1    forward 35som notwis pike     26  forward 35som notwis pike
# 2    reverse 35som notwis tuck     45  reverse 35som notwis tuck
# 3       back 25som 15twis pike      5     back 25som 15twis pike
# 4       back 25som 15twis pike      5     back 25som 15twis pike

# %%
merged_final = merged.drop(columns=["best", "most_common_index", "ok", 0, "matched_vocab_indices", "matched_diving48_classes"])

# %%
merged_final.to_csv("CoverstionOfFineDivingToDiving48.csv")

# %%
merged_final
# Out:
#                                  label  finediving_count  \
# 0                    Inward 35som TUCK               345
# 1                   Forward 35som PIKE               322
# 2                   Reverse 35som TUCK               231
# 3                      Back 25som PIKE               205
# 4               Back 15Twis 25som PIKE               203
# 5                      Back 35som TUCK               159
# 6                   Forward 45som TUCK               158
# 7                    Inward 25som PIKE               132
# 8             Forward 25som PIKE 2Twis               110
# 9             Forward 25som PIKE 1Twis                94
# 10                  Reverse 05som PIKE                87
# 11                  Reverse 25som PIKE                82
# 12              Back 25Twis 25som PIKE                79
# 13                     Back 35som PIKE                73
# 14                     Back 05som PIKE                70
# 15                  Reverse 25som TUCK                57
# 16                  Forward 15som PIKE                36
# 17                   Inward 05som PIKE                36
# 18            Forward 25som PIKE 3Twis                36
# 19           Reverse 15Twis 25som PIKE                31
# 20                   Inward 15som PIKE                23
# 21                  Forward 05som PIKE                22
# 22           Reverse 35Twis 15som PIKE                21
# 23                  Forward 35som TUCK                18
# 24                   Inward 25som TUCK                18
# 25                     Back 25som TUCK                16
# 26              Back 05Twis 15som PIKE                12
# 27              Back 25Twis 15som PIKE                11
# 28            Forward 15som PIKE 1Twis                 9
# 29                   Inward 35som PIKE                 8
# 30              Back 05Twis 25som PIKE                 7
# 31                  Forward 25som PIKE                 6
# 32                   Inward 45som TUCK                 5
# 33  Forward 1som PIKE 2Twis 15som PIKE                 4
# 34           Reverse 05Twis 15som PIKE                 4
# 35              Back 15Twis 15som PIKE                 4
# 36            Forward 35som PIKE 1Twis                 3
# 37           Reverse 25Twis 25som PIKE                 3
# 38           Reverse 25Twis 15som PIKE                 2
# 39              Back 35Twis 15som PIKE                 2
# 40                  Reverse 15som TUCK                 1
# 41           Reverse 35Twis 15som TUCK                 1
# 42                   Reverse 3som TUCK                 1
# 43           Forward 35Twis 15som PIKE                 1
# 44                    Inward 1som PIKE                 1
# 45                  Forward 45som PIKE                 1
# 46            Forward 25som TUCK 2Twis                 1
# 47  Forward 1som PIKE 3Twis 25som PIKE                 1
# 48           Forward 15Twis 25som PIKE                 1
# 49            Forward 05Twis 2som PIKE                 1
# 50               Back 25Twis 2som TUCK                 1
# 51               Back 15Twis 2som PIKE                 1
# 52                  Reverse 45som TUCK                 1
#
#    matched_diving48_classes_str  index
# 0      inward 35som notwis tuck     35
# 1     forward 35som notwis pike     26
# 2     reverse 35som notwis tuck     45
# 3        back 25som 15twis pike      5
# 4        back 25som 15twis pike      5
# 5        back 35som notwis tuck     12
# 6     forward 45som notwis tuck     28
# 7      inward 25som notwis pike     33
# 8      forward 25som 2twis pike     22
# 9      forward 25som 1twis pike     21
# 10    reverse 15som notwis pike     41
# 11    reverse 25som 15twis pike     42
# 12       back 25som 25twis pike      6
# 13       back 35som notwis pike     11
# 14       back 15som notwis pike      3
# 15    reverse 25som notwis tuck     44
# 16    forward 15som notwis pike     19
# 17     inward 15som notwis pike     31
# 18     forward 25som 3twis pike     23
# 19    reverse 25som 15twis pike     42
# 20     inward 15som notwis pike     31
# 21    forward 15som notwis pike     19
# 22    reverse 15som 35twis free     40
# 23    forward 35som notwis tuck     27
# 24     inward 25som notwis tuck     34
# 25       back 25som notwis tuck      8
# 26       back 15som 05twis free      0
# 27       back 15som 25twis free      2
# 28     forward 15som 1twis free     17
# 29       back 35som notwis pike     11
# 30       back 25som 15twis pike      5
# 31     forward 25som 3twis pike     23
# 32    forward 45som notwis tuck     28
# 33     forward 15som 2twis free     18
# 34    reverse 15som 05twis free     37
# 35       back 15som 15twis free      1
# 36     forward 25som 1twis pike     21
# 37       back 25som 25twis pike      6
# 38    reverse 15som 25twis free     39
# 39       back 15som notwis pike      3
# 40       back 15som notwis tuck      4
# 41    reverse 15som 35twis free     40
# 42        back 3som notwis tuck     14
# 43    forward 15som notwis pike     19
# 44     forward 1som notwis pike     20
# 45    forward 15som notwis pike     19
# 46     forward 25som 2twis pike     22
# 47     forward 25som 3twis pike     23
# 48       back 25som 15twis pike      5
# 49    forward 15som notwis pike     19
# 50        back 2som 25twis free     10
# 51       back 25som 15twis pike      5
# 52    forward 45som notwis tuck     28

# %%
import matplotlib.pyplot as plt

grouped_df = merged_final.groupby('index')['finediving_count'].sum().reset_index()

# 2. Merge one class name per index (we'll just use the first occurrence)
class_names = merged_final[['index', 'matched_diving48_classes_str']].drop_duplicates(subset='index')
summary_df = grouped_df.merge(class_names, on='index', how='left')

# 3. Sort by count descending
summary_df.sort_values(by='finediving_count', ascending=False, inplace=True)

# 4. Plot
plt.figure(figsize=(14, 6))
plt.bar(summary_df['matched_diving48_classes_str'], summary_df['finediving_count'])
plt.xticks(rotation=90)
plt.xlabel("Diving48 Class")
plt.ylabel("FineDiving Sample Count")
plt.title("FineDiving Count per Diving48 Class (Grouped by Index)")
plt.tight_layout()
plt.show()

# 5. Optional: save or print
print(summary_df.head())
# Out:
#     index  finediving_count matched_diving48_classes_str
# 5       5               417       back 25som 15twis pike
# 25     35               345     inward 35som notwis tuck
# 19     26               322    forward 35som notwis pike
# 32     45               231    reverse 35som notwis tuck
# 21     28               164    forward 45som notwis tuck

# %%
df_result
# Out:
#       Unnamed: 0    id   code        0       1      2     3    4    5  \
# 0              0     1   407c   Inward   35som   TUCK   NaN  NaN  NaN
# 1              1     2   407c   Inward   35som   TUCK   NaN  NaN  NaN
# 2              2     3  5253b     Back  15Twis  25som  PIKE  NaN  NaN
# 3              3     4   407c   Inward   35som   TUCK   NaN  NaN  NaN
# 4              4     5  5253b     Back  15Twis  25som  PIKE  NaN  NaN
# ...          ...   ...    ...      ...     ...    ...   ...  ...  ...
# 2752        2995  2996  5253b     Back  15Twis  25som  PIKE  NaN  NaN
# 2753        2996  2997   109c  Forward   45som   TUCK   NaN  NaN  NaN
# 2754        2997  2998  5255b     Back  25Twis  25som  PIKE  NaN  NaN
# 2755        2998  2999  5253b     Back  15Twis  25som  PIKE  NaN  NaN
# 2756        2999  3000  5255b     Back  25Twis  25som  PIKE  NaN  NaN
#
#                        label              matched_class match_type  \
# 0          Inward 35som TUCK   inward 35som notwis tuck         ok
# 1          Inward 35som TUCK   inward 35som notwis tuck         ok
# 2     Back 15Twis 25som PIKE     back 25som 15twis pike         ok
# 3          Inward 35som TUCK   inward 35som notwis tuck         ok
# 4     Back 15Twis 25som PIKE     back 25som 15twis pike         ok
# ...                      ...                        ...        ...
# 2752  Back 15Twis 25som PIKE     back 25som 15twis pike         ok
# 2753      Forward 45som TUCK  forward 45som notwis tuck         ok
# 2754  Back 25Twis 25som PIKE     back 25som 25twis pike         ok
# 2755  Back 15Twis 25som PIKE     back 25som 15twis pike         ok
# 2756  Back 25Twis 25som PIKE     back 25som 25twis pike         ok
#
#       matched_vocab_index
# 0                      -1
# 1                      -1
# 2                      -1
# 3                      -1
# 4                      -1
# ...                   ...
# 2752                   -1
# 2753                   -1
# 2754                   -1
# 2755                   -1
# 2756                   -1
#
# [2757 rows x 13 columns]

# %%
mergedFullVideo = df_result.merge(merged_final, left_on='matched_class', right_on="matched_diving48_classes_str", how='left')

# %%
mergedFullVideo = mergedFullVideo.drop(columns=["match_type","matched_vocab_index","Unnamed: 0"  ])

# %%
mergedFullVideo
# Out:
#         id   code       0       1      2     3    4    5  \
# 0        1   407c  Inward   35som   TUCK   NaN  NaN  NaN
# 1        2   407c  Inward   35som   TUCK   NaN  NaN  NaN
# 2        3  5253b    Back  15Twis  25som  PIKE  NaN  NaN
# 3        3  5253b    Back  15Twis  25som  PIKE  NaN  NaN
# 4        3  5253b    Back  15Twis  25som  PIKE  NaN  NaN
# ...    ...    ...     ...     ...    ...   ...  ...  ...
# 5715  2999  5253b    Back  15Twis  25som  PIKE  NaN  NaN
# 5716  2999  5253b    Back  15Twis  25som  PIKE  NaN  NaN
# 5717  2999  5253b    Back  15Twis  25som  PIKE  NaN  NaN
# 5718  3000  5255b    Back  25Twis  25som  PIKE  NaN  NaN
# 5719  3000  5255b    Back  25Twis  25som  PIKE  NaN  NaN
#
#                      label_x             matched_class  \
# 0          Inward 35som TUCK  inward 35som notwis tuck
# 1          Inward 35som TUCK  inward 35som notwis tuck
# 2     Back 15Twis 25som PIKE    back 25som 15twis pike
# 3     Back 15Twis 25som PIKE    back 25som 15twis pike
# 4     Back 15Twis 25som PIKE    back 25som 15twis pike
# ...                      ...                       ...
# 5715  Back 15Twis 25som PIKE    back 25som 15twis pike
# 5716  Back 15Twis 25som PIKE    back 25som 15twis pike
# 5717  Back 15Twis 25som PIKE    back 25som 15twis pike
# 5718  Back 25Twis 25som PIKE    back 25som 25twis pike
# 5719  Back 25Twis 25som PIKE    back 25som 25twis pike
#
#                         label_y  finediving_count  \
# 0             Inward 35som TUCK               345
# 1             Inward 35som TUCK               345
# 2               Back 25som PIKE               205
# 3        Back 15Twis 25som PIKE               203
# 4        Back 05Twis 25som PIKE                 7
# ...                         ...               ...
# 5715     Back 05Twis 25som PIKE                 7
# 5716  Forward 15Twis 25som PIKE                 1
# 5717      Back 15Twis 2som PIKE                 1
# 5718     Back 25Twis 25som PIKE                79
# 5719  Reverse 25Twis 25som PIKE                 3
#
#      matched_diving48_classes_str  index
# 0        inward 35som notwis tuck     35
# 1        inward 35som notwis tuck     35
# 2          back 25som 15twis pike      5
# 3          back 25som 15twis pike      5
# 4          back 25som 15twis pike      5
# ...                           ...    ...
# 5715       back 25som 15twis pike      5
# 5716       back 25som 15twis pike      5
# 5717       back 25som 15twis pike      5
# 5718       back 25som 25twis pike      6
# 5719       back 25som 25twis pike      6
#
# [5720 rows x 14 columns]

# %%
def remove_duplicates(df: pd.DataFrame, subset_cols=None) -> pd.DataFrame:
    """
    Removes duplicate rows from the DataFrame.
    
    Parameters:
        df (pd.DataFrame): Input DataFrame
        subset_cols (list or None): Columns to consider for identifying duplicates.
                                    If None, all columns are used.
    
    Returns:
        pd.DataFrame: Deduplicated DataFrame
    """
    if subset_cols:
        deduped_df = df.drop_duplicates(subset=subset_cols)
    else:
        deduped_df = df.drop_duplicates()

    return deduped_df.reset_index(drop=True)

# %%
mergedFullVideo.columns
# Out:
# Index(['id', 'code', '0', '1', '2', '3', '4', '5', 'label_x', 'matched_class',
#        'label_y', 'finediving_count', 'matched_diving48_classes_str', 'index'],
#       dtype='object')

# %%
mergedFullVideo
# Out:
#         id   code       0       1      2     3    4    5  \
# 0        1   407c  Inward   35som   TUCK   NaN  NaN  NaN
# 1        2   407c  Inward   35som   TUCK   NaN  NaN  NaN
# 2        3  5253b    Back  15Twis  25som  PIKE  NaN  NaN
# 3        3  5253b    Back  15Twis  25som  PIKE  NaN  NaN
# 4        3  5253b    Back  15Twis  25som  PIKE  NaN  NaN
# ...    ...    ...     ...     ...    ...   ...  ...  ...
# 5715  2999  5253b    Back  15Twis  25som  PIKE  NaN  NaN
# 5716  2999  5253b    Back  15Twis  25som  PIKE  NaN  NaN
# 5717  2999  5253b    Back  15Twis  25som  PIKE  NaN  NaN
# 5718  3000  5255b    Back  25Twis  25som  PIKE  NaN  NaN
# 5719  3000  5255b    Back  25Twis  25som  PIKE  NaN  NaN
#
#                      label_x             matched_class  \
# 0          Inward 35som TUCK  inward 35som notwis tuck
# 1          Inward 35som TUCK  inward 35som notwis tuck
# 2     Back 15Twis 25som PIKE    back 25som 15twis pike
# 3     Back 15Twis 25som PIKE    back 25som 15twis pike
# 4     Back 15Twis 25som PIKE    back 25som 15twis pike
# ...                      ...                       ...
# 5715  Back 15Twis 25som PIKE    back 25som 15twis pike
# 5716  Back 15Twis 25som PIKE    back 25som 15twis pike
# 5717  Back 15Twis 25som PIKE    back 25som 15twis pike
# 5718  Back 25Twis 25som PIKE    back 25som 25twis pike
# 5719  Back 25Twis 25som PIKE    back 25som 25twis pike
#
#                         label_y  finediving_count  \
# 0             Inward 35som TUCK               345
# 1             Inward 35som TUCK               345
# 2               Back 25som PIKE               205
# 3        Back 15Twis 25som PIKE               203
# 4        Back 05Twis 25som PIKE                 7
# ...                         ...               ...
# 5715     Back 05Twis 25som PIKE                 7
# 5716  Forward 15Twis 25som PIKE                 1
# 5717      Back 15Twis 2som PIKE                 1
# 5718     Back 25Twis 25som PIKE                79
# 5719  Reverse 25Twis 25som PIKE                 3
#
#      matched_diving48_classes_str  index
# 0        inward 35som notwis tuck     35
# 1        inward 35som notwis tuck     35
# 2          back 25som 15twis pike      5
# 3          back 25som 15twis pike      5
# 4          back 25som 15twis pike      5
# ...                           ...    ...
# 5715       back 25som 15twis pike      5
# 5716       back 25som 15twis pike      5
# 5717       back 25som 15twis pike      5
# 5718       back 25som 25twis pike      6
# 5719       back 25som 25twis pike      6
#
# [5720 rows x 14 columns]
