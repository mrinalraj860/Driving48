# %%
import numpy as np 
import pandas as pd

# %%
RGBtrained = pd.read_csv("RGBVIDEOTrained/rgb_per_class_accuracy.csv")

# %%
RGBtrained
# Out:
#     Class  Accuracy (%)  Correct  Total  Unnamed: 4  Unnamed: 5
# 0       0          0.00        0     60         NaN    0.084207
# 1       1          2.50        1     40         NaN         NaN
# 2       2          0.00        0     15         NaN         NaN
# 3       3         66.67       38     57         NaN         NaN
# 4       4          0.00        0      5         NaN         NaN
# 5       5         51.16       66    129         NaN         NaN
# 6       6         13.33        6     45         NaN         NaN
# 7       7          0.00        0    162         NaN         NaN
# 8       8          5.31        6    113         NaN         NaN
# 9       9         10.00        2     20         NaN         NaN
# 10     10          0.00        0      9         NaN         NaN
# 11     11          0.00        0     39         NaN         NaN
# 12     12          2.83        3    106         NaN         NaN
# 13     13          0.00        0      3         NaN         NaN
# 14     14         26.67        4     15         NaN         NaN
# 15     15          5.32       10    188         NaN         NaN
# 16     16          0.00        0      9         NaN         NaN
# 17     17          2.44        3    123         NaN         NaN
# 18     18         30.00        6     20         NaN         NaN
# 19     19          0.00        0    160         NaN         NaN
# 20     20         22.22        2      9         NaN         NaN
# 21     21          3.03        5    165         NaN         NaN
# 22     22          1.82        1     55         NaN         NaN
# 23     23          0.00        0     11         NaN         NaN
# 24     24          3.94        5    127         NaN         NaN
# 25     25          0.00        0     10         NaN         NaN
# 26     26          3.83        8    209         NaN         NaN
# 27     27          1.52        1     66         NaN         NaN
# 28     28          3.17        2     63         NaN         NaN
# 29     29          0.00        0     41         NaN         NaN
# 30     30         44.14       64    145         NaN         NaN
# 31     31          0.00        0      8         NaN         NaN
# 32     32          9.21        7     76         NaN         NaN
# 33     33          2.96        4    135         NaN         NaN
# 34     34          0.00        0    114         NaN         NaN
# 35     35          1.08        1     93         NaN         NaN
# 36     36          0.00        0     15         NaN         NaN
# 37     37          3.57        1     28         NaN         NaN
# 38     38          0.00        0     13         NaN         NaN
# 39     39          0.00        0      8         NaN         NaN
# 40     40         20.00        5     25         NaN         NaN
# 41     41          0.00        0     15         NaN         NaN
# 42     42          1.49        1     67         NaN         NaN
# 43     43          3.68        6    163         NaN         NaN
# 44     44          2.65        3    113         NaN         NaN
# 45     45          8.37       20    239         NaN         NaN
# 46     46          0.00        0      6         NaN         NaN

# %%
def top5_classes_weighted_accuracy(csv_path):
    df = pd.read_csv(csv_path)
    
    # Get top 5 classes by accuracy
    top5_df = df.nlargest(5, 'Accuracy (%)')

    # Calculate weighted accuracy
    correct_preds = (top5_df['Accuracy (%)'] * top5_df['Total']).sum()
    total_samples = top5_df['Total'].sum()
    
    weighted_accuracy = correct_preds / total_samples
    
    return weighted_accuracy, top5_df

weighted_acc, top5_classes = top5_classes_weighted_accuracy("RGBVIDEOTrained/rgb_per_class_accuracy.csv")

print("Weighted Accuracy for Top-5 Classes:", weighted_acc)
print(top5_classes)
# Out:
# Weighted Accuracy for Top-5 Classes: 48.63437158469945
#     Class  Accuracy (%)  Correct  Total  Unnamed: 4  Unnamed: 5
# 3       3         66.67       38     57         NaN         NaN
# 5       5         51.16       66    129         NaN         NaN
# 30     30         44.14       64    145         NaN         NaN
# 18     18         30.00        6     20         NaN         NaN
# 14     14         26.67        4     15         NaN         NaN

# %%
top5_classes["Correct"].sum()/top5_classes["Total"].sum()
# Out:
# np.float64(0.48633879781420764)

# %% [markdown]
# ## This is the End of top5 from Raw RGB

# %%
CNNNGRUTest = pd.read_csv("/Users/mrinalraj/Downloads/WebDownload/Driving48/TrainCNNGRU/Epoch_50/per_class_accuracy.csv")

# %%
def top5_classes_weighted_accuracyForPointTracks(csv_path):
    df = pd.read_csv(csv_path)
    
    # Get top 5 classes by accuracy
    top5_df = df.nlargest(5, 'Accuracy')

    # Calculate weighted accuracy
    correct_preds = (top5_df['Accuracy (%)'] * top5_df['Total']).sum()
    total_samples = top5_df['Total'].sum()
    
    weighted_accuracy = correct_preds / total_samples
    
    return weighted_accuracy, top5_df

weighted_acc, top5_classes = top5_classes_weighted_accuracy("RGBVIDEOTrained/rgb_per_class_accuracy.csv")

print("Weighted Accuracy for Top-5 Classes:", weighted_acc)
print(top5_classes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Accuracy (%)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 top5_classes_weighted_accuracy("/Users/mrinalraj/Downloads/WebDownload/Driving48/TrainCNNGRU/Epoch_50/per_class_accuracy.csv")
#
# Cell In[6], line 5, in top5_classes_weighted_accuracy(csv_path)
#       2 df = pd.read_csv(csv_path)
#       4 # Get top 5 classes by accuracy
# ----> 5 top5_df = df.nlargest(5, 'Accuracy (%)')
#       7 # Calculate weighted accuracy
#       8 correct_preds = (top5_df['Accuracy (%)'] * top5_df['Total']).sum()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:7651, in DataFrame.nlargest(self, n, columns, keep)
#    7532 def nlargest(
#    7533     self, n: int, columns: IndexLabel, keep: NsmallestNlargestKeep = "first"
#    7534 ) -> DataFrame:
#    7535     """
#    7536     Return the first `n` rows ordered by `columns` in descending order.
#    7537
#    (...)
#    7649     Brunei      434000    12128      BN
#    7650     """
# -> 7651     return selectn.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/methods/selectn.py:57, in SelectN.nlargest(self)
#      55 @final
#      56 def nlargest(self):
# ---> 57     return self.compute("nlargest")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/methods/selectn.py:199, in SelectNFrame.compute(self, method)
#     196 columns = self.columns
#     198 for column in columns:
# --> 199     dtype = frame[column].dtype
#     200     if not self.is_valid_dtype_n_method(dtype):
#     201         raise TypeError(
#     202             f"Column {repr(column)} has dtype {dtype}, "
#     203             f"cannot use method {repr(method)} with this dtype"
#     204         )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Accuracy (%)'

# %%
CNNNGRUTest
# Out:
#        Class  Accuracy  Total_Samples  Correct_Predictions
# 0    Class_0  0.033333             60                    2
# 1    Class_1  0.025000             40                    1
# 2    Class_2  0.066667             15                    1
# 3    Class_3  0.385965             57                   22
# 4    Class_4  0.000000              5                    0
# 5    Class_5  0.178295            129                   23
# 6    Class_6  0.200000             45                    9
# 7    Class_7  0.043210            162                    7
# 8    Class_8  0.070796            113                    8
# 9    Class_9  0.150000             20                    3
# 10  Class_10  0.000000              9                    0
# 11  Class_11  0.076923             39                    3
# 12  Class_12  0.150943            106                   16
# 13  Class_13  0.000000              3                    0
# 14  Class_14  0.266667             15                    4
# 15  Class_15  0.053191            188                   10
# 16  Class_16  0.000000              9                    0
# 17  Class_17  0.024390            123                    3
# 18  Class_18  0.050000             20                    1
# 19  Class_19  0.056250            160                    9
# 20  Class_20  0.555556              9                    5
# 21  Class_21  0.048485            165                    8
# 22  Class_22  0.145455             55                    8
# 23  Class_23  0.181818             11                    2
# 24  Class_24  0.244094            127                   31
# 25  Class_25  0.100000             10                    1
# 26  Class_26  0.081340            209                   17
# 27  Class_27  0.075758             66                    5
# 28  Class_28  0.174603             63                   11
# 29  Class_29  0.097561             41                    4
# 30  Class_30  0.124138            145                   18
# 31  Class_31  0.125000              8                    1
# 32  Class_32  0.144737             76                   11
# 33  Class_33  0.051852            135                    7
# 34  Class_34  0.035088            114                    4
# 35  Class_35  0.021505             93                    2
# 36  Class_36  0.133333             15                    2
# 37  Class_37  0.035714             28                    1
# 38  Class_38  0.076923             13                    1
# 39  Class_39  0.000000              8                    0
# 40  Class_40  0.240000             25                    6
# 41  Class_41  0.333333             15                    5
# 42  Class_42  0.104478             67                    7
# 43  Class_43  0.092025            163                   15
# 44  Class_44  0.256637            113                   29
# 45  Class_45  0.121339            239                   29
# 46  Class_46  0.000000              6                    0
