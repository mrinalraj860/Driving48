# %%
model_path = "/Users/mrinalraj/Downloads/WebDownload/Driving48/saved_models_model1/model_epoch_96_acc_90.79.pt"

import torch

checkpoint = torch.load(model_path, map_location='cpu')
print(type(checkpoint))
# Out:
# <class 'collections.OrderedDict'>

# %%
for k, v in checkpoint.items():
    print(f"{k:40} {tuple(v.shape)}")
# Out:
# cls_token                                (1, 1, 128)
# point_pos_emb                            (1, 1001, 128)
# temporal_encoder.weight_ih_l0            (384, 3)
# temporal_encoder.weight_hh_l0            (384, 128)
# temporal_encoder.bias_ih_l0              (384,)
# temporal_encoder.bias_hh_l0              (384,)
# transformer.layers.0.self_attn.in_proj_weight (384, 128)
# transformer.layers.0.self_attn.in_proj_bias (384,)
# transformer.layers.0.self_attn.out_proj.weight (128, 128)
# transformer.layers.0.self_attn.out_proj.bias (128,)
# transformer.layers.0.linear1.weight      (256, 128)
# transformer.layers.0.linear1.bias        (256,)
# transformer.layers.0.linear2.weight      (128, 256)
# transformer.layers.0.linear2.bias        (128,)
# transformer.layers.0.norm1.weight        (128,)
# transformer.layers.0.norm1.bias          (128,)
# transformer.layers.0.norm2.weight        (128,)
# transformer.layers.0.norm2.bias          (128,)
# transformer.layers.1.self_attn.in_proj_weight (384, 128)
# transformer.layers.1.self_attn.in_proj_bias (384,)
# transformer.layers.1.self_attn.out_proj.weight (128, 128)
# transformer.layers.1.self_attn.out_proj.bias (128,)
# transformer.layers.1.linear1.weight      (256, 128)
# transformer.layers.1.linear1.bias        (256,)
# transformer.layers.1.linear2.weight      (128, 256)
# transformer.layers.1.linear2.bias        (128,)
# transformer.layers.1.norm1.weight        (128,)
# transformer.layers.1.norm1.bias          (128,)
# transformer.layers.1.norm2.weight        (128,)
# transformer.layers.1.norm2.bias          (128,)
# transformer.layers.2.self_attn.in_proj_weight (384, 128)
# transformer.layers.2.self_attn.in_proj_bias (384,)
# transformer.layers.2.self_attn.out_proj.weight (128, 128)
# transformer.layers.2.self_attn.out_proj.bias (128,)
# transformer.layers.2.linear1.weight      (256, 128)
# transformer.layers.2.linear1.bias        (256,)
# transformer.layers.2.linear2.weight      (128, 256)
# transformer.layers.2.linear2.bias        (128,)
# transformer.layers.2.norm1.weight        (128,)
# transformer.layers.2.norm1.bias          (128,)
# transformer.layers.2.norm2.weight        (128,)
# transformer.layers.2.norm2.bias          (128,)
# transformer.layers.3.self_attn.in_proj_weight (384, 128)
# transformer.layers.3.self_attn.in_proj_bias (384,)
# transformer.layers.3.self_attn.out_proj.weight (128, 128)
# transformer.layers.3.self_attn.out_proj.bias (128,)
# transformer.layers.3.linear1.weight      (256, 128)
# transformer.layers.3.linear1.bias        (256,)
# transformer.layers.3.linear2.weight      (128, 256)
# transformer.layers.3.linear2.bias        (128,)
# transformer.layers.3.norm1.weight        (128,)
# transformer.layers.3.norm1.bias          (128,)
# transformer.layers.3.norm2.weight        (128,)
# transformer.layers.3.norm2.bias          (128,)
# fc.weight                                (47, 128)
# fc.bias                                  (47,)
